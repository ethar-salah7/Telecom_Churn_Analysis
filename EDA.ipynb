# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('bronze.csv')

# %%
df.head()
# Out:
#   customer_id  gender  age married  number_of_dependents          city  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    zip_code   latitude   longitude  number_of_referrals  ...  monthly_charge  \
# 0     93225  34.827662 -118.999073                    2  ...            65.6
# 1     91206  34.162515 -118.203869                    0  ...            -4.0
# 2     92627  33.645672 -117.922613                    0  ...            73.9
# 3     94553  38.014457 -122.115432                    1  ...            98.0
# 4     93010  34.227846 -119.079903                    3  ...            83.9
#
#   total_charges total_refunds  total_extra_data_charges  \
# ...

# %%
df.shape
# Out:
# (7043, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 39 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   customer_id                        7043 non-null   object
#  1   gender                             7043 non-null   object
#  2   age                                7043 non-null   int64
#  3   married                            7043 non-null   object
#  4   number_of_dependents               7043 non-null   int64
#  5   city                               7043 non-null   object
#  6   zip_code                           7043 non-null   int64
#  7   latitude                           7043 non-null   float64
#  8   longitude                          7043 non-null   float64
#  9   number_of_referrals                7043 non-null   int64
#  10  tenure_in_months                   7043 non-null   int64
# ...

# %%
df.describe()
# Out:
#                age  number_of_dependents      zip_code     latitude  \
# count  7043.000000           7043.000000   7043.000000  7043.000000
# mean     46.509726              0.468692  93486.070567    36.197455
# std      16.750352              0.962802   1856.767505     2.468929
# min      19.000000              0.000000  90001.000000    32.555828
# 25%      32.000000              0.000000  92101.000000    33.990646
# 50%      46.000000              0.000000  93518.000000    36.205465
# 75%      60.000000              0.000000  95329.000000    38.161321
# max      80.000000              9.000000  96150.000000    41.962127
#
#          longitude  number_of_referrals  tenure_in_months  \
# count  7043.000000          7043.000000       7043.000000
# mean   -119.756684             1.951867         32.386767
# std       2.154425             3.001199         24.542061
# min    -124.301372             0.000000          1.000000
# 25%    -121.788090             0.000000          9.000000
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'married', 'number_of_dependents',
#        'city', 'zip_code', 'latitude', 'longitude', 'number_of_referrals',
#        'tenure_in_months', 'offer', 'phone_service',
#        'avg_monthly_long_distance_charges', 'multiple_lines',
#        'internet_service', 'internet_type', 'avg_monthly_gb_download',
#        'online_security', 'online_backup', 'device_protection_plan',
#        'premium_tech_support', 'streaming_tv', 'streaming_movies',
#        'streaming_music', 'unlimited_data', 'contract', 'paperless_billing',
#        'payment_method', 'monthly_charge', 'total_charges', 'total_refunds',
#        'total_extra_data_charges', 'total_long_distance_charges',
#        'total_revenue', 'customer_status', 'churn_category', 'churn_reason',
#        'ingestion_date'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
for col in df.select_dtypes(include='object').columns:
    print(f'unique vales {col}:{df[col].value_counts()}')
# Out:
# unique vales customer_id:customer_id
# 0002-ORFBO    1
# 6616-AALSR    1
# 6625-UTXEW    1
# 6625-IUTTT    1
# 6625-FLENO    1
# 6624-JDRDS    1
# 6621-YOBKI    1
# 6621-NRZAK    1
# 6620-JDYNW    1
# 6620-HVDUJ    1
# 6619-RPLQZ    1
# 6618-RYATB    1
# 6617-WLBQC    1
# 6615-ZGEDR    1
# 6629-CZTTH    1
# 6615-NGGZJ    1
# 6614-YWYSC    1
# 6614-YOLAC    1
# 6614-VBEGU    1
# 6614-FHDBO    1
# 6609-MXJHJ    1
# 6608-QQLVK    1
# 6603-YRDCJ    1
# 6603-QWSPR    1
# 6599-SFQVE    1
# 6599-RCLCJ    1
# 6627-CFOSN    1
# 6629-LADHQ    1
# 7452-FOLON    1
# 6648-INWPS    1
# 6661-EIPZC    1
# 6656-JWRQX    1
# 6656-GULJQ    1
# 6655-LHBYW    1
# 6654-QGBZZ    1
# 6653-CBBOM    1
# 6652-YFFJO    1
# 6651-RLGGM    1
# 6651-AZVTJ    1
# 6650-VJONK    1
# 6650-BWFRT    1
# 6647-ZEDXT    1
# 6630-UJZMY    1
# 6646-VRFOL    1
# 6646-QVXLR    1
# 6646-JPPHA    1
# 6645-MXQJT    1
# 6641-XRPSU    1
# 6637-KYRCV    1
# 6635-MYYYZ    1
# 6635-CPNUN    1
# 6633-SYEUS    1
# 6633-MPWBS    1
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                             0
# gender                                  0
# age                                     0
# married                                 0
# number_of_dependents                    0
# city                                    0
# zip_code                                0
# latitude                                0
# longitude                               0
# number_of_referrals                     0
# tenure_in_months                        0
# offer                                3877
# phone_service                           0
# avg_monthly_long_distance_charges     682
# multiple_lines                        682
# internet_service                        0
# internet_type                        1526
# avg_monthly_gb_download              1526
# online_security                      1526
# online_backup                        1526
# device_protection_plan               1526
# premium_tech_support                 1526
# ...

# %%
for col in df.select_dtypes(include='number').columns:
    sns.histplot(df[col], kde=True)
    plt.title(col)
    plt.show()

# %%
df['offer'].value_counts()
# Out:
# offer
# Offer B    824
# Offer E    805
# Offer D    602
# Offer A    520
# Offer C    415
# Name: count, dtype: int64

# %%
df[df['avg_monthly_long_distance_charges'].isna()]['phone_service'].value_counts()
# Out:
# phone_service
# No    682
# Name: count, dtype: int64

# %%
df[df['multiple_lines'].isna()]['phone_service'].value_counts()
# Out:
# phone_service
# No    682
# Name: count, dtype: int64

# %%
df['internet_type'].value_counts()
# Out:
# internet_type
# Fiber Optic    3035
# DSL            1652
# Cable           830
# Name: count, dtype: int64

# %%
df[df['internet_type'].isna()]['internet_service'].value_counts()
# Out:
# internet_service
# No    1526
# Name: count, dtype: int64

# %%
df[df['unlimited_data'].isna()]['internet_service'].value_counts()
# Out:
# internet_service
# No    1526
# Name: count, dtype: int64

# %%
df['unlimited_data'].value_counts()
# Out:
# unlimited_data
# Yes    4745
# No      772
# Name: count, dtype: int64

# %%
df['churn_category'].value_counts()
# Out:
# churn_category
# Competitor         841
# Dissatisfaction    321
# Attitude           314
# Price              211
# Other              182
# Name: count, dtype: int64

# %%
df[df['churn_category'].isna()]['customer_status'].value_counts()
# Out:
# customer_status
# Stayed    4720
# Joined     454
# Name: count, dtype: int64

# %%
df['customer_status'].value_counts()
# Out:
# customer_status
# Stayed     4720
# Churned    1869
# Joined      454
# Name: count, dtype: int64

# %%
df[df['monthly_charge'] < 0]
# Out:
#      customer_id  gender  age married  number_of_dependents  \
# 1     0003-MKNFE    Male   46      No                     0
# 32    0052-DCKON    Male   28     Yes                     0
# 170   0274-JKUJR    Male   21     Yes                     2
# 232   0361-HJRDX  Female   38      No                     0
# 336   0495-ZBNGW    Male   78     Yes                     0
# 428   0623-IIHUG  Female   77      No                     0
# 571   0840-DCNZE    Male   33      No                     0
# 692   1024-GUALD  Female   29     Yes                     0
# 694   1024-VRZHF    Male   39     Yes                     0
# 702   1036-GUDCL    Male   59     Yes                     3
# 734   1084-UQCHV    Male   35      No                     0
# 900   1307-TVUFB    Male   66      No                     0
# 934   1353-LJWEM    Male   23      No                     0
# 966   1399-UBQIU    Male   35      No                     0
# 991   1439-LCGVL  Female   42     Yes                     0
# ...

# %%
print(df[['monthly_charge', 'total_refunds']].corr())
sns.scatterplot(data=df, x='total_refunds', y='monthly_charge')
# Out:
#                 monthly_charge  total_refunds
# monthly_charge        1.000000       0.023963
# total_refunds         0.023963       1.000000
# <Axes: xlabel='total_refunds', ylabel='monthly_charge'>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# check negative values
numeric_cols = df.select_dtypes(include=['number']).columns
for col in numeric_cols:
    if (df[col] < 0).any():
        print(col)
# Out:
# longitude
# monthly_charge

# %%
df['churn_reason'].value_counts()
# Out:
# churn_reason
# Competitor had better devices                313
# Competitor made better offer                 311
# Attitude of support person                   220
# Don't know                                   130
# Competitor offered more data                 117
# Competitor offered higher download speeds    100
# Attitude of service provider                  94
# Price too high                                78
# Product dissatisfaction                       77
# Network reliability                           72
# Long distance charges                         64
# Service dissatisfaction                       63
# Moved                                         46
# Extra data charges                            39
# Limited range of services                     37
# Poor expertise of online support              31
# Lack of affordable download/upload speed      30
# Lack of self-service on Website               29
# Poor expertise of phone support               12
# ...

# %%
df['churn_category'].value_counts()
# Out:
# churn_category
# Competitor         841
# Dissatisfaction    321
# Attitude           314
# Price              211
# Other              182
# Name: count, dtype: int64

# %%
df['number_of_referrals'].value_counts()
# Out:
# number_of_referrals
# 0     3821
# 1     1086
# 5      264
# 3      255
# 7      248
# 9      238
# 2      236
# 4      236
# 10     223
# 6      221
# 8      213
# 11       2
# Name: count, dtype: int64
